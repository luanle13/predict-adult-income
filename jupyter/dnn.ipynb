# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
import os
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# %%
df_train = pd.read_csv('../data/adult.data')
df_train.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df_test = pd.read_csv('../data/adult.test')
df_test.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18          ?  103497  Some-college             10       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
label_encoders = {}
for column in df_train.select_dtypes(include=['object']).columns:
    labels = df_train[column].unique()
    with open(f'../categories/{column}.txt', 'w') as file:
        for label in labels:
            file.write(f'{label}\n')

# %%
mapping_folder_path = '../categories'
file_extension = '.txt'
file_list = [file_name for file_name in os.listdir(mapping_folder_path) if file_name.endswith(file_extension)]

for file_name in file_list:
    column = file_name.split('.')[0]
    with open(f'../categories/{file_name}', 'r') as file:
        labels = []
        for line in file:
            labels.append(line.strip())
        label_encoder = LabelEncoder()
        label_encoder.fit(labels)
        df_train[column] = label_encoder.transform(df_train[column])
        df_test[column] = label_encoder.transform(df_test[column])

df_train = df_train.dropna()
df_test = df_test.dropna()
X_train = df_train.drop('income', axis=1).drop('fnlwgt', axis=1)
y_train = df_train['income']
X_test = df_test.drop('income', axis=1).drop('fnlwgt', axis=1)
y_test = df_test['income']

# %%
# scaler = StandardScaler()
# scaler.fit(X_train)
# x_std = scaler.transform(X_test.head(1))

# %%
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_train_std = X_train_std.astype('float32')
X_test_std = scaler.transform(X_test)
X_test_std = X_test_std.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_std.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train_std, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 814/814 [==============================] - 1s 828us/step - loss: 0.3510 - accuracy: 0.8360 - val_loss: 0.3247 - val_accuracy: 0.8455
# Epoch 2/100
# 814/814 [==============================] - 1s 723us/step - loss: 0.3263 - accuracy: 0.8479 - val_loss: 0.3225 - val_accuracy: 0.8448
# Epoch 3/100
# 814/814 [==============================] - 1s 720us/step - loss: 0.3216 - accuracy: 0.8499 - val_loss: 0.3209 - val_accuracy: 0.8483
# Epoch 4/100
# 814/814 [==============================] - 1s 734us/step - loss: 0.3189 - accuracy: 0.8511 - val_loss: 0.3276 - val_accuracy: 0.8451
# Epoch 5/100
# 814/814 [==============================] - 1s 712us/step - loss: 0.3168 - accuracy: 0.8504 - val_loss: 0.3189 - val_accuracy: 0.8485
# Epoch 6/100
# 814/814 [==============================] - 1s 728us/step - loss: 0.3149 - accuracy: 0.8532 - val_loss: 0.3184 - val_accuracy: 0.8517
# Epoch 7/100
# 814/814 [==============================] - 1s 742us/step - loss: 0.3132 - accuracy: 0.8543 - val_loss: 0.3226 - val_accuracy: 0.8474
# Epoch 8/100
# 814/814 [==============================] - 1s 728us/step - loss: 0.3117 - accuracy: 0.8544 - val_loss: 0.3205 - val_accuracy: 0.8523
# Epoch 9/100
# 814/814 [==============================] - 1s 704us/step - loss: 0.3094 - accuracy: 0.8559 - val_loss: 0.3157 - val_accuracy: 0.8505
# Epoch 10/100
# 814/814 [==============================] - 1s 732us/step - loss: 0.3088 - accuracy: 0.8555 - val_loss: 0.3175 - val_accuracy: 0.8506
# Epoch 11/100
# 814/814 [==============================] - 1s 721us/step - loss: 0.3066 - accuracy: 0.8554 - val_loss: 0.3169 - val_accuracy: 0.8506
# Epoch 12/100
# 814/814 [==============================] - 1s 749us/step - loss: 0.3048 - accuracy: 0.8578 - val_loss: 0.3175 - val_accuracy: 0.8534
# Epoch 13/100
# 814/814 [==============================] - 1s 732us/step - loss: 0.3043 - accuracy: 0.8568 - val_loss: 0.3219 - val_accuracy: 0.8486
# Epoch 14/100
# 814/814 [==============================] - 1s 731us/step - loss: 0.3020 - accuracy: 0.8583 - val_loss: 0.3240 - val_accuracy: 0.8474
# Epoch 15/100
# 814/814 [==============================] - 1s 720us/step - loss: 0.3019 - accuracy: 0.8592 - val_loss: 0.3162 - val_accuracy: 0.8497
# Epoch 16/100
# 814/814 [==============================] - 1s 722us/step - loss: 0.2993 - accuracy: 0.8598 - val_loss: 0.3226 - val_accuracy: 0.8491
# Epoch 17/100
# 814/814 [==============================] - 1s 725us/step - loss: 0.2982 - accuracy: 0.8601 - val_loss: 0.3196 - val_accuracy: 0.8501
# Epoch 18/100
# 814/814 [==============================] - 1s 756us/step - loss: 0.2971 - accuracy: 0.8605 - val_loss: 0.3183 - val_accuracy: 0.8480
# Epoch 19/100
# 814/814 [==============================] - 1s 753us/step - loss: 0.2959 - accuracy: 0.8608 - val_loss: 0.3170 - val_accuracy: 0.8523
# Epoch 20/100
# 814/814 [==============================] - 1s 756us/step - loss: 0.2949 - accuracy: 0.8616 - val_loss: 0.3189 - val_accuracy: 0.8469
# Epoch 21/100
# 814/814 [==============================] - 1s 728us/step - loss: 0.2936 - accuracy: 0.8634 - val_loss: 0.3241 - val_accuracy: 0.8492
# Epoch 22/100
# 814/814 [==============================] - 1s 747us/step - loss: 0.2929 - accuracy: 0.8618 - val_loss: 0.3164 - val_accuracy: 0.8523
# Epoch 23/100
# 814/814 [==============================] - 1s 732us/step - loss: 0.2913 - accuracy: 0.8621 - val_loss: 0.3188 - val_accuracy: 0.8529
# Epoch 24/100
# 814/814 [==============================] - 1s 686us/step - loss: 0.2904 - accuracy: 0.8638 - val_loss: 0.3243 - val_accuracy: 0.8471
# Epoch 25/100
# 814/814 [==============================] - 1s 695us/step - loss: 0.2890 - accuracy: 0.8638 - val_loss: 0.3241 - val_accuracy: 0.8458
# Epoch 26/100
# 814/814 [==============================] - 1s 684us/step - loss: 0.2884 - accuracy: 0.8633 - val_loss: 0.3217 - val_accuracy: 0.8475
# Epoch 27/100
# 814/814 [==============================] - 1s 703us/step - loss: 0.2874 - accuracy: 0.8637 - val_loss: 0.3217 - val_accuracy: 0.8481
# Epoch 28/100
# 814/814 [==============================] - 1s 701us/step - loss: 0.2856 - accuracy: 0.8660 - val_loss: 0.3226 - val_accuracy: 0.8474
# Epoch 29/100
# 814/814 [==============================] - 1s 727us/step - loss: 0.2861 - accuracy: 0.8652 - val_loss: 0.3235 - val_accuracy: 0.8483
# Epoch 30/100
# 814/814 [==============================] - 1s 713us/step - loss: 0.2837 - accuracy: 0.8654 - val_loss: 0.3278 - val_accuracy: 0.8471
# Epoch 31/100
# 814/814 [==============================] - 1s 680us/step - loss: 0.2840 - accuracy: 0.8654 - val_loss: 0.3257 - val_accuracy: 0.8488
# Epoch 32/100
# 814/814 [==============================] - 1s 688us/step - loss: 0.2817 - accuracy: 0.8660 - val_loss: 0.3310 - val_accuracy: 0.8455
# Epoch 33/100
# 814/814 [==============================] - 1s 683us/step - loss: 0.2815 - accuracy: 0.8664 - val_loss: 0.3251 - val_accuracy: 0.8475
# Epoch 34/100
# 814/814 [==============================] - 1s 678us/step - loss: 0.2807 - accuracy: 0.8680 - val_loss: 0.3308 - val_accuracy: 0.8475
# Epoch 35/100
# 814/814 [==============================] - 1s 673us/step - loss: 0.2789 - accuracy: 0.8680 - val_loss: 0.3279 - val_accuracy: 0.8486
# Epoch 36/100
# 814/814 [==============================] - 1s 689us/step - loss: 0.2786 - accuracy: 0.8676 - val_loss: 0.3321 - val_accuracy: 0.8457
# Epoch 37/100
# 814/814 [==============================] - 1s 681us/step - loss: 0.2774 - accuracy: 0.8680 - val_loss: 0.3300 - val_accuracy: 0.8460
# Epoch 38/100
# 814/814 [==============================] - 1s 677us/step - loss: 0.2768 - accuracy: 0.8689 - val_loss: 0.3310 - val_accuracy: 0.8477
# Epoch 39/100
# 814/814 [==============================] - 1s 667us/step - loss: 0.2754 - accuracy: 0.8697 - val_loss: 0.3310 - val_accuracy: 0.8471
# Epoch 40/100
# 814/814 [==============================] - 1s 673us/step - loss: 0.2737 - accuracy: 0.8699 - val_loss: 0.3347 - val_accuracy: 0.8446
# Epoch 41/100
# 814/814 [==============================] - 1s 664us/step - loss: 0.2737 - accuracy: 0.8709 - val_loss: 0.3351 - val_accuracy: 0.8475
# Epoch 42/100
# 814/814 [==============================] - 1s 656us/step - loss: 0.2717 - accuracy: 0.8707 - val_loss: 0.3380 - val_accuracy: 0.8437
# Epoch 43/100
# 814/814 [==============================] - 1s 678us/step - loss: 0.2723 - accuracy: 0.8700 - val_loss: 0.3377 - val_accuracy: 0.8432
# Epoch 44/100
# 814/814 [==============================] - 1s 685us/step - loss: 0.2705 - accuracy: 0.8720 - val_loss: 0.3427 - val_accuracy: 0.8448
# Epoch 45/100
# 814/814 [==============================] - 1s 699us/step - loss: 0.2697 - accuracy: 0.8720 - val_loss: 0.3476 - val_accuracy: 0.8435
# Epoch 46/100
# 814/814 [==============================] - 1s 718us/step - loss: 0.2687 - accuracy: 0.8725 - val_loss: 0.3417 - val_accuracy: 0.8429
# Epoch 47/100
# 814/814 [==============================] - 1s 689us/step - loss: 0.2678 - accuracy: 0.8738 - val_loss: 0.3408 - val_accuracy: 0.8457
# Epoch 48/100
# 814/814 [==============================] - 1s 688us/step - loss: 0.2677 - accuracy: 0.8740 - val_loss: 0.3515 - val_accuracy: 0.8426
# Epoch 49/100
# 814/814 [==============================] - 1s 695us/step - loss: 0.2670 - accuracy: 0.8714 - val_loss: 0.3387 - val_accuracy: 0.8429
# Epoch 50/100
# 814/814 [==============================] - 1s 696us/step - loss: 0.2658 - accuracy: 0.8731 - val_loss: 0.3458 - val_accuracy: 0.8415
# Epoch 51/100
# 814/814 [==============================] - 1s 689us/step - loss: 0.2645 - accuracy: 0.8758 - val_loss: 0.3467 - val_accuracy: 0.8458
# Epoch 52/100
# 814/814 [==============================] - 1s 690us/step - loss: 0.2633 - accuracy: 0.8752 - val_loss: 0.3504 - val_accuracy: 0.8392
# Epoch 53/100
# 814/814 [==============================] - 1s 701us/step - loss: 0.2632 - accuracy: 0.8748 - val_loss: 0.3473 - val_accuracy: 0.8445
# Epoch 54/100
# 814/814 [==============================] - 1s 694us/step - loss: 0.2622 - accuracy: 0.8748 - val_loss: 0.3443 - val_accuracy: 0.8448
# Epoch 55/100
# 814/814 [==============================] - 1s 677us/step - loss: 0.2607 - accuracy: 0.8764 - val_loss: 0.3521 - val_accuracy: 0.8420
# Epoch 56/100
# 814/814 [==============================] - 1s 678us/step - loss: 0.2596 - accuracy: 0.8770 - val_loss: 0.3530 - val_accuracy: 0.8431
# Epoch 57/100
# 814/814 [==============================] - 1s 685us/step - loss: 0.2601 - accuracy: 0.8761 - val_loss: 0.3512 - val_accuracy: 0.8446
# Epoch 58/100
# 814/814 [==============================] - 1s 689us/step - loss: 0.2594 - accuracy: 0.8757 - val_loss: 0.3556 - val_accuracy: 0.8422
# Epoch 59/100
# 814/814 [==============================] - 1s 704us/step - loss: 0.2589 - accuracy: 0.8771 - val_loss: 0.3566 - val_accuracy: 0.8431
# Epoch 60/100
# 814/814 [==============================] - 1s 691us/step - loss: 0.2574 - accuracy: 0.8764 - val_loss: 0.3581 - val_accuracy: 0.8422
# Epoch 61/100
# 814/814 [==============================] - 1s 688us/step - loss: 0.2568 - accuracy: 0.8786 - val_loss: 0.3558 - val_accuracy: 0.8426
# Epoch 62/100
# 814/814 [==============================] - 1s 653us/step - loss: 0.2556 - accuracy: 0.8796 - val_loss: 0.3573 - val_accuracy: 0.8422
# Epoch 63/100
# 814/814 [==============================] - 1s 669us/step - loss: 0.2550 - accuracy: 0.8785 - val_loss: 0.3627 - val_accuracy: 0.8386
# Epoch 64/100
# 814/814 [==============================] - 1s 702us/step - loss: 0.2535 - accuracy: 0.8803 - val_loss: 0.3651 - val_accuracy: 0.8334
# Epoch 65/100
# 814/814 [==============================] - 1s 701us/step - loss: 0.2541 - accuracy: 0.8794 - val_loss: 0.3635 - val_accuracy: 0.8388
# Epoch 66/100
# 814/814 [==============================] - 1s 708us/step - loss: 0.2526 - accuracy: 0.8791 - val_loss: 0.3684 - val_accuracy: 0.8359
# Epoch 67/100
# 814/814 [==============================] - 1s 678us/step - loss: 0.2530 - accuracy: 0.8801 - val_loss: 0.3620 - val_accuracy: 0.8429
# Epoch 68/100
# 814/814 [==============================] - 1s 694us/step - loss: 0.2510 - accuracy: 0.8813 - val_loss: 0.3619 - val_accuracy: 0.8376
# Epoch 69/100
# 814/814 [==============================] - 1s 698us/step - loss: 0.2494 - accuracy: 0.8808 - val_loss: 0.3692 - val_accuracy: 0.8442
# Epoch 70/100
# 814/814 [==============================] - 1s 697us/step - loss: 0.2501 - accuracy: 0.8819 - val_loss: 0.3689 - val_accuracy: 0.8417
# Epoch 71/100
# 814/814 [==============================] - 1s 685us/step - loss: 0.2494 - accuracy: 0.8810 - val_loss: 0.3721 - val_accuracy: 0.8474
# Epoch 72/100
# 814/814 [==============================] - 1s 679us/step - loss: 0.2482 - accuracy: 0.8808 - val_loss: 0.3732 - val_accuracy: 0.8380
# Epoch 73/100
# 814/814 [==============================] - 1s 685us/step - loss: 0.2477 - accuracy: 0.8812 - val_loss: 0.3708 - val_accuracy: 0.8411
# Epoch 74/100
# 814/814 [==============================] - 1s 704us/step - loss: 0.2475 - accuracy: 0.8825 - val_loss: 0.3799 - val_accuracy: 0.8388
# Epoch 75/100
# 814/814 [==============================] - 1s 690us/step - loss: 0.2461 - accuracy: 0.8835 - val_loss: 0.3730 - val_accuracy: 0.8357
# Epoch 76/100
# 814/814 [==============================] - 1s 677us/step - loss: 0.2473 - accuracy: 0.8827 - val_loss: 0.3766 - val_accuracy: 0.8392
# Epoch 77/100
# 814/814 [==============================] - 1s 689us/step - loss: 0.2447 - accuracy: 0.8841 - val_loss: 0.3744 - val_accuracy: 0.8439
# Epoch 78/100
# 814/814 [==============================] - 1s 692us/step - loss: 0.2439 - accuracy: 0.8834 - val_loss: 0.3853 - val_accuracy: 0.8405
# Epoch 79/100
# 814/814 [==============================] - 1s 689us/step - loss: 0.2437 - accuracy: 0.8840 - val_loss: 0.3832 - val_accuracy: 0.8434
# Epoch 80/100
# 814/814 [==============================] - 1s 705us/step - loss: 0.2424 - accuracy: 0.8843 - val_loss: 0.3868 - val_accuracy: 0.8434
# Epoch 81/100
# 814/814 [==============================] - 1s 701us/step - loss: 0.2432 - accuracy: 0.8837 - val_loss: 0.3979 - val_accuracy: 0.8297
# Epoch 82/100
# 814/814 [==============================] - 1s 705us/step - loss: 0.2412 - accuracy: 0.8849 - val_loss: 0.3817 - val_accuracy: 0.8386
# Epoch 83/100
# 814/814 [==============================] - 1s 697us/step - loss: 0.2407 - accuracy: 0.8846 - val_loss: 0.3886 - val_accuracy: 0.8397
# Epoch 84/100
# 814/814 [==============================] - 1s 693us/step - loss: 0.2410 - accuracy: 0.8862 - val_loss: 0.3883 - val_accuracy: 0.8343
# Epoch 85/100
# 814/814 [==============================] - 1s 685us/step - loss: 0.2399 - accuracy: 0.8866 - val_loss: 0.3949 - val_accuracy: 0.8383
# Epoch 86/100
# 814/814 [==============================] - 1s 701us/step - loss: 0.2398 - accuracy: 0.8852 - val_loss: 0.3937 - val_accuracy: 0.8354
# Epoch 87/100
# 814/814 [==============================] - 1s 686us/step - loss: 0.2381 - accuracy: 0.8871 - val_loss: 0.3880 - val_accuracy: 0.8408
# Epoch 88/100
# 814/814 [==============================] - 1s 701us/step - loss: 0.2375 - accuracy: 0.8871 - val_loss: 0.3951 - val_accuracy: 0.8331
# Epoch 89/100
# 814/814 [==============================] - 1s 679us/step - loss: 0.2372 - accuracy: 0.8894 - val_loss: 0.3929 - val_accuracy: 0.8392
# Epoch 90/100
# 814/814 [==============================] - 1s 678us/step - loss: 0.2367 - accuracy: 0.8870 - val_loss: 0.3969 - val_accuracy: 0.8366
# Epoch 91/100
# 814/814 [==============================] - 1s 692us/step - loss: 0.2373 - accuracy: 0.8874 - val_loss: 0.3999 - val_accuracy: 0.8385
# Epoch 92/100
# 814/814 [==============================] - 1s 694us/step - loss: 0.2361 - accuracy: 0.8872 - val_loss: 0.3976 - val_accuracy: 0.8368
# Epoch 93/100
# 814/814 [==============================] - 1s 692us/step - loss: 0.2355 - accuracy: 0.8885 - val_loss: 0.4028 - val_accuracy: 0.8400
# Epoch 94/100
# 814/814 [==============================] - 1s 681us/step - loss: 0.2348 - accuracy: 0.8884 - val_loss: 0.3972 - val_accuracy: 0.8360
# Epoch 95/100
# 814/814 [==============================] - 1s 679us/step - loss: 0.2338 - accuracy: 0.8897 - val_loss: 0.4082 - val_accuracy: 0.8303
# Epoch 96/100
# 814/814 [==============================] - 1s 700us/step - loss: 0.2317 - accuracy: 0.8887 - val_loss: 0.4094 - val_accuracy: 0.8319
# Epoch 97/100
# 814/814 [==============================] - 1s 687us/step - loss: 0.2331 - accuracy: 0.8907 - val_loss: 0.4101 - val_accuracy: 0.8313
# Epoch 98/100
# 814/814 [==============================] - 1s 726us/step - loss: 0.2326 - accuracy: 0.8888 - val_loss: 0.4168 - val_accuracy: 0.8326
# Epoch 99/100
# 814/814 [==============================] - 1s 692us/step - loss: 0.2306 - accuracy: 0.8910 - val_loss: 0.4133 - val_accuracy: 0.8371
# Epoch 100/100
# 814/814 [==============================] - 1s 690us/step - loss: 0.2308 - accuracy: 0.8905 - val_loss: 0.4084 - val_accuracy: 0.8422

# %%
y_pred_proba = model.predict(X_test_std)
y_pred = (y_pred_proba > 0.5).astype(int)
# Out:
# 509/509 [==============================] - 0s 443us/step

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.84

# %%
model.save_weights('../weights/dnn.h5')
model.save('../models/dnn')
# Out:
# INFO:tensorflow:Assets written to: ../models/dnn\assets
# INFO:tensorflow:Assets written to: ../models/dnn\assets
