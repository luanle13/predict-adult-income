# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
import os
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Works\predict-adult-income\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df_train = pd.read_csv('../data/adult.data')
df_train.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df_test = pd.read_csv('../data/adult.test')
df_test.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18          ?  103497  Some-college             10       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
label_encoders = {}
for column in df_train.select_dtypes(include=['object']).columns:
    labels = df_train[column].unique()
    with open(f'../categories/{column}.txt', 'w') as file:
        for label in labels:
            file.write(f'{label}\n')

# %%
mapping_folder_path = '../categories'
file_extension = '.txt'
file_list = [file_name for file_name in os.listdir(mapping_folder_path) if file_name.endswith(file_extension)]

map_dict = {}
for file_name in file_list:
    column = file_name.split('.')[0]
    with open(f'../categories/{file_name}', 'r') as file:
        labels = []
        for line in file:
            labels.append(line.strip())
        label_encoder = LabelEncoder()
        label_encoder.fit(labels)
        df_train[column] = label_encoder.transform(df_train[column])
        df_test[column] = label_encoder.transform(df_test[column])

df_train = df_train.dropna()
df_test = df_test.dropna()
X_train = df_train.drop('income', axis=1).drop('fnlwgt', axis=1)
y_train = df_train['income']
X_test = df_test.drop('income', axis=1).drop('fnlwgt', axis=1)
y_test = df_test['income']

# %%
# scaler = StandardScaler()
# scaler.fit(X_train)
# x_std = scaler.transform(X_test.head(1))

# %%
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_train_std = X_train_std.astype('float32')
X_test_std = scaler.transform(X_test)
X_test_std = X_test_std.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_std.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid'),
])
# Out:
# WARNING:tensorflow:From c:\Works\predict-adult-income\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Works\predict-adult-income\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_train_std, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Works\predict-adult-income\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Works\predict-adult-income\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 814/814 [==============================] - 1s 849us/step - loss: 0.3520 - accuracy: 0.8370 - val_loss: 0.3241 - val_accuracy: 0.8465
# Epoch 2/100
# 814/814 [==============================] - 1s 755us/step - loss: 0.3265 - accuracy: 0.8471 - val_loss: 0.3238 - val_accuracy: 0.8440
# Epoch 3/100
# 814/814 [==============================] - 1s 723us/step - loss: 0.3216 - accuracy: 0.8504 - val_loss: 0.3226 - val_accuracy: 0.8457
# Epoch 4/100
# 814/814 [==============================] - 1s 731us/step - loss: 0.3187 - accuracy: 0.8507 - val_loss: 0.3216 - val_accuracy: 0.8506
# Epoch 5/100
# 814/814 [==============================] - 1s 708us/step - loss: 0.3163 - accuracy: 0.8526 - val_loss: 0.3199 - val_accuracy: 0.8480
# Epoch 6/100
# 814/814 [==============================] - 1s 721us/step - loss: 0.3134 - accuracy: 0.8546 - val_loss: 0.3192 - val_accuracy: 0.8486
# Epoch 7/100
# 814/814 [==============================] - 1s 745us/step - loss: 0.3120 - accuracy: 0.8537 - val_loss: 0.3200 - val_accuracy: 0.8492
# Epoch 8/100
# 814/814 [==============================] - 1s 722us/step - loss: 0.3112 - accuracy: 0.8542 - val_loss: 0.3199 - val_accuracy: 0.8477
# Epoch 9/100
# 814/814 [==============================] - 1s 717us/step - loss: 0.3088 - accuracy: 0.8553 - val_loss: 0.3189 - val_accuracy: 0.8485
# Epoch 10/100
# 814/814 [==============================] - 1s 728us/step - loss: 0.3065 - accuracy: 0.8561 - val_loss: 0.3194 - val_accuracy: 0.8529
# Epoch 11/100
# 814/814 [==============================] - 1s 731us/step - loss: 0.3058 - accuracy: 0.8581 - val_loss: 0.3203 - val_accuracy: 0.8506
# Epoch 12/100
# 814/814 [==============================] - 1s 760us/step - loss: 0.3042 - accuracy: 0.8583 - val_loss: 0.3233 - val_accuracy: 0.8458
# Epoch 13/100
# 814/814 [==============================] - 1s 732us/step - loss: 0.3028 - accuracy: 0.8593 - val_loss: 0.3187 - val_accuracy: 0.8485
# Epoch 14/100
# 814/814 [==============================] - 1s 771us/step - loss: 0.3008 - accuracy: 0.8593 - val_loss: 0.3206 - val_accuracy: 0.8537
# Epoch 15/100
# 814/814 [==============================] - 1s 729us/step - loss: 0.3003 - accuracy: 0.8586 - val_loss: 0.3196 - val_accuracy: 0.8492
# Epoch 16/100
# 814/814 [==============================] - 1s 766us/step - loss: 0.2983 - accuracy: 0.8598 - val_loss: 0.3202 - val_accuracy: 0.8505
# Epoch 17/100
# 814/814 [==============================] - 1s 737us/step - loss: 0.2967 - accuracy: 0.8616 - val_loss: 0.3209 - val_accuracy: 0.8500
# Epoch 18/100
# 814/814 [==============================] - 1s 796us/step - loss: 0.2959 - accuracy: 0.8624 - val_loss: 0.3209 - val_accuracy: 0.8466
# Epoch 19/100
# 814/814 [==============================] - 1s 739us/step - loss: 0.2942 - accuracy: 0.8628 - val_loss: 0.3223 - val_accuracy: 0.8492
# Epoch 20/100
# 814/814 [==============================] - 1s 737us/step - loss: 0.2931 - accuracy: 0.8629 - val_loss: 0.3225 - val_accuracy: 0.8454
# Epoch 21/100
# 814/814 [==============================] - 1s 742us/step - loss: 0.2919 - accuracy: 0.8632 - val_loss: 0.3240 - val_accuracy: 0.8483
# Epoch 22/100
# 814/814 [==============================] - 1s 728us/step - loss: 0.2915 - accuracy: 0.8641 - val_loss: 0.3211 - val_accuracy: 0.8517
# Epoch 23/100
# 814/814 [==============================] - 1s 741us/step - loss: 0.2886 - accuracy: 0.8647 - val_loss: 0.3252 - val_accuracy: 0.8488
# Epoch 24/100
# 814/814 [==============================] - 1s 738us/step - loss: 0.2876 - accuracy: 0.8651 - val_loss: 0.3218 - val_accuracy: 0.8498
# Epoch 25/100
# 814/814 [==============================] - 1s 727us/step - loss: 0.2862 - accuracy: 0.8658 - val_loss: 0.3254 - val_accuracy: 0.8497
# Epoch 26/100
# 814/814 [==============================] - 1s 743us/step - loss: 0.2854 - accuracy: 0.8651 - val_loss: 0.3280 - val_accuracy: 0.8466
# Epoch 27/100
# 814/814 [==============================] - 1s 749us/step - loss: 0.2843 - accuracy: 0.8688 - val_loss: 0.3296 - val_accuracy: 0.8434
# Epoch 28/100
# 814/814 [==============================] - 1s 744us/step - loss: 0.2837 - accuracy: 0.8669 - val_loss: 0.3331 - val_accuracy: 0.8440
# Epoch 29/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2819 - accuracy: 0.8679 - val_loss: 0.3300 - val_accuracy: 0.8463
# Epoch 30/100
# 814/814 [==============================] - 1s 1ms/step - loss: 0.2804 - accuracy: 0.8682 - val_loss: 0.3309 - val_accuracy: 0.8474
# Epoch 31/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2798 - accuracy: 0.8695 - val_loss: 0.3285 - val_accuracy: 0.8471
# Epoch 32/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2784 - accuracy: 0.8676 - val_loss: 0.3299 - val_accuracy: 0.8471
# Epoch 33/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2771 - accuracy: 0.8694 - val_loss: 0.3277 - val_accuracy: 0.8492
# Epoch 34/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2763 - accuracy: 0.8700 - val_loss: 0.3333 - val_accuracy: 0.8445
# Epoch 35/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2748 - accuracy: 0.8712 - val_loss: 0.3310 - val_accuracy: 0.8465
# Epoch 36/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2745 - accuracy: 0.8716 - val_loss: 0.3329 - val_accuracy: 0.8501
# Epoch 37/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2725 - accuracy: 0.8714 - val_loss: 0.3364 - val_accuracy: 0.8449
# Epoch 38/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2721 - accuracy: 0.8717 - val_loss: 0.3322 - val_accuracy: 0.8501
# Epoch 39/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2712 - accuracy: 0.8723 - val_loss: 0.3343 - val_accuracy: 0.8485
# Epoch 40/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2702 - accuracy: 0.8722 - val_loss: 0.3316 - val_accuracy: 0.8468
# Epoch 41/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2694 - accuracy: 0.8736 - val_loss: 0.3366 - val_accuracy: 0.8471
# Epoch 42/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2672 - accuracy: 0.8746 - val_loss: 0.3389 - val_accuracy: 0.8448
# Epoch 43/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2673 - accuracy: 0.8752 - val_loss: 0.3383 - val_accuracy: 0.8451
# Epoch 44/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2655 - accuracy: 0.8737 - val_loss: 0.3426 - val_accuracy: 0.8419
# Epoch 45/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2652 - accuracy: 0.8753 - val_loss: 0.3415 - val_accuracy: 0.8454
# Epoch 46/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2638 - accuracy: 0.8755 - val_loss: 0.3425 - val_accuracy: 0.8478
# Epoch 47/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2630 - accuracy: 0.8759 - val_loss: 0.3412 - val_accuracy: 0.8417
# Epoch 48/100
# 814/814 [==============================] - 1s 1ms/step - loss: 0.2621 - accuracy: 0.8758 - val_loss: 0.3467 - val_accuracy: 0.8434
# Epoch 49/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2602 - accuracy: 0.8779 - val_loss: 0.3515 - val_accuracy: 0.8460
# Epoch 50/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2594 - accuracy: 0.8771 - val_loss: 0.3480 - val_accuracy: 0.8437
# Epoch 51/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2587 - accuracy: 0.8780 - val_loss: 0.3484 - val_accuracy: 0.8415
# Epoch 52/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2576 - accuracy: 0.8791 - val_loss: 0.3498 - val_accuracy: 0.8396
# Epoch 53/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2568 - accuracy: 0.8789 - val_loss: 0.3484 - val_accuracy: 0.8429
# Epoch 54/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2566 - accuracy: 0.8793 - val_loss: 0.3494 - val_accuracy: 0.8431
# Epoch 55/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2549 - accuracy: 0.8806 - val_loss: 0.3495 - val_accuracy: 0.8432
# Epoch 56/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2542 - accuracy: 0.8812 - val_loss: 0.3514 - val_accuracy: 0.8392
# Epoch 57/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2544 - accuracy: 0.8803 - val_loss: 0.3552 - val_accuracy: 0.8412
# Epoch 58/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2523 - accuracy: 0.8806 - val_loss: 0.3475 - val_accuracy: 0.8457
# Epoch 59/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2513 - accuracy: 0.8821 - val_loss: 0.3567 - val_accuracy: 0.8446
# Epoch 60/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2513 - accuracy: 0.8834 - val_loss: 0.3548 - val_accuracy: 0.8435
# Epoch 61/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2504 - accuracy: 0.8803 - val_loss: 0.3577 - val_accuracy: 0.8420
# Epoch 62/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2499 - accuracy: 0.8829 - val_loss: 0.3577 - val_accuracy: 0.8434
# Epoch 63/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2478 - accuracy: 0.8835 - val_loss: 0.3623 - val_accuracy: 0.8415
# Epoch 64/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2478 - accuracy: 0.8835 - val_loss: 0.3571 - val_accuracy: 0.8477
# Epoch 65/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2466 - accuracy: 0.8827 - val_loss: 0.3608 - val_accuracy: 0.8458
# Epoch 66/100
# 814/814 [==============================] - 1s 1ms/step - loss: 0.2452 - accuracy: 0.8851 - val_loss: 0.3661 - val_accuracy: 0.8412
# Epoch 67/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2454 - accuracy: 0.8855 - val_loss: 0.3652 - val_accuracy: 0.8400
# Epoch 68/100
# 814/814 [==============================] - 1s 1ms/step - loss: 0.2436 - accuracy: 0.8849 - val_loss: 0.3653 - val_accuracy: 0.8434
# Epoch 69/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2454 - accuracy: 0.8843 - val_loss: 0.3603 - val_accuracy: 0.8445
# Epoch 70/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2440 - accuracy: 0.8848 - val_loss: 0.3660 - val_accuracy: 0.8419
# Epoch 71/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2424 - accuracy: 0.8848 - val_loss: 0.3646 - val_accuracy: 0.8411
# Epoch 72/100
# 814/814 [==============================] - 1s 1ms/step - loss: 0.2413 - accuracy: 0.8869 - val_loss: 0.3733 - val_accuracy: 0.8412
# Epoch 73/100
# 814/814 [==============================] - 1s 1ms/step - loss: 0.2417 - accuracy: 0.8856 - val_loss: 0.3762 - val_accuracy: 0.8366
# Epoch 74/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2403 - accuracy: 0.8864 - val_loss: 0.3772 - val_accuracy: 0.8380
# Epoch 75/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2389 - accuracy: 0.8879 - val_loss: 0.3768 - val_accuracy: 0.8371
# Epoch 76/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2392 - accuracy: 0.8867 - val_loss: 0.3720 - val_accuracy: 0.8434
# Epoch 77/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2371 - accuracy: 0.8892 - val_loss: 0.3854 - val_accuracy: 0.8366
# Epoch 78/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2373 - accuracy: 0.8888 - val_loss: 0.3751 - val_accuracy: 0.8397
# Epoch 79/100
# 814/814 [==============================] - 1s 2ms/step - loss: 0.2391 - accuracy: 0.8862 - val_loss: 0.3870 - val_accuracy: 0.8409
# Epoch 80/100
# 814/814 [==============================] - 2s 2ms/step - loss: 0.2368 - accuracy: 0.8889 - val_loss: 0.3782 - val_accuracy: 0.8442
# Epoch 81/100
# 814/814 [==============================] - 1s 1ms/step - loss: 0.2354 - accuracy: 0.8893 - val_loss: 0.3861 - val_accuracy: 0.8402
# Epoch 82/100
# 814/814 [==============================] - 1s 1ms/step - loss: 0.2348 - accuracy: 0.8902 - val_loss: 0.3798 - val_accuracy: 0.8380
# Epoch 83/100
# 814/814 [==============================] - 1s 915us/step - loss: 0.2347 - accuracy: 0.8903 - val_loss: 0.3884 - val_accuracy: 0.8359
# Epoch 84/100
# 814/814 [==============================] - 1s 679us/step - loss: 0.2331 - accuracy: 0.8898 - val_loss: 0.3861 - val_accuracy: 0.8386
# Epoch 85/100
# 814/814 [==============================] - 1s 673us/step - loss: 0.2330 - accuracy: 0.8889 - val_loss: 0.4011 - val_accuracy: 0.8359
# Epoch 86/100
# 814/814 [==============================] - 1s 660us/step - loss: 0.2323 - accuracy: 0.8899 - val_loss: 0.3859 - val_accuracy: 0.8382
# Epoch 87/100
# 814/814 [==============================] - 1s 665us/step - loss: 0.2330 - accuracy: 0.8905 - val_loss: 0.3936 - val_accuracy: 0.8394
# Epoch 88/100
# 814/814 [==============================] - 1s 664us/step - loss: 0.2327 - accuracy: 0.8902 - val_loss: 0.3928 - val_accuracy: 0.8374
# Epoch 89/100
# 814/814 [==============================] - 1s 675us/step - loss: 0.2310 - accuracy: 0.8906 - val_loss: 0.3949 - val_accuracy: 0.8415
# Epoch 90/100
# 814/814 [==============================] - 1s 675us/step - loss: 0.2289 - accuracy: 0.8929 - val_loss: 0.3982 - val_accuracy: 0.8376
# Epoch 91/100
# 814/814 [==============================] - 1s 667us/step - loss: 0.2295 - accuracy: 0.8913 - val_loss: 0.3994 - val_accuracy: 0.8328
# Epoch 92/100
# 814/814 [==============================] - 1s 667us/step - loss: 0.2289 - accuracy: 0.8912 - val_loss: 0.4033 - val_accuracy: 0.8325
# Epoch 93/100
# 814/814 [==============================] - 1s 670us/step - loss: 0.2300 - accuracy: 0.8905 - val_loss: 0.4005 - val_accuracy: 0.8386
# Epoch 94/100
# 814/814 [==============================] - 1s 668us/step - loss: 0.2281 - accuracy: 0.8907 - val_loss: 0.4027 - val_accuracy: 0.8368
# Epoch 95/100
# 814/814 [==============================] - 1s 673us/step - loss: 0.2266 - accuracy: 0.8933 - val_loss: 0.4109 - val_accuracy: 0.8333
# Epoch 96/100
# 814/814 [==============================] - 1s 678us/step - loss: 0.2266 - accuracy: 0.8924 - val_loss: 0.4075 - val_accuracy: 0.8389
# Epoch 97/100
# 814/814 [==============================] - 1s 685us/step - loss: 0.2265 - accuracy: 0.8929 - val_loss: 0.4075 - val_accuracy: 0.8353
# Epoch 98/100
# 814/814 [==============================] - 1s 677us/step - loss: 0.2266 - accuracy: 0.8932 - val_loss: 0.4029 - val_accuracy: 0.8343
# Epoch 99/100
# 814/814 [==============================] - 1s 713us/step - loss: 0.2246 - accuracy: 0.8945 - val_loss: 0.4172 - val_accuracy: 0.8391
# Epoch 100/100
# 814/814 [==============================] - 1s 678us/step - loss: 0.2238 - accuracy: 0.8948 - val_loss: 0.4079 - val_accuracy: 0.8311

# %%
y_pred_proba = model.predict(X_test_std)
y_pred = (y_pred_proba > 0.5).astype(int)
# Out:
# 509/509 [==============================] - 0s 441us/step

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.83

# %%
model.save_weights('../weights/dnn.h5')
